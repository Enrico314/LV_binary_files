# %% [markdown]
# # This is a sample jupyter notebook
#
# It will become the documentation at some point on how to run the things

# %%
# make sure you ran `pip install -e .` before!

# %%
from LV_binary_files.obj_a import ObjA

# %%
obj = ObjA("TestObj_Init")

# %%
print(obj)
# Out:
# TestObj_Init

# %%
print(obj.get_random())
# Out:
# 0.09515428337591525
